# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
# sentences
sent = ['the glass of milk',
        'the glass of juice',
        'the cup of tea',
        'I am a good boy',
        'I am a good developer',
        'Understand the meaning of words',
        'Your videos are good']

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'Understand the meaning of words',
#  'Your videos are good']

# %%
# Define the vocabulary size
voc_size = 10000

# %%
# One hot representation
one_hot_repr = [one_hot(words, voc_size) for words in sent]
one_hot_repr
# Out:
# [[7218, 2478, 3743, 2866],
#  [7218, 2478, 3743, 200],
#  [7218, 9420, 3743, 1399],
#  [5842, 6565, 2269, 2340, 494],
#  [5842, 6565, 2269, 2340, 1972],
#  [763, 7218, 1855, 3743, 9378],
#  [5096, 319, 6781, 2340]]

# %%
# import libraries
import numpy as np
from tensorflow.keras.layers import Embedding, Input
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
sent_length = 8
embedded_docs = pad_sequences(one_hot_repr, padding='pre', maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 7218 2478 3743 2866]
#  [   0    0    0    0 7218 2478 3743  200]
#  [   0    0    0    0 7218 9420 3743 1399]
#  [   0    0    0 5842 6565 2269 2340  494]
#  [   0    0    0 5842 6565 2269 2340 1972]
#  [   0    0    0  763 7218 1855 3743 9378]
#  [   0    0    0    0 5096  319 6781 2340]]

# %%
# feature representation
dim = 10

# %%
model = Sequential()
model.add(Input(shape=(sent_length,)))
model.add(Embedding(voc_size, dim))
model.compile('adam', 'mse')

# %%
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_4 (Embedding)              │ (None, 8, 10)               │         100,000 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# array([[[-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [ 0.02090422,  0.03870109, -0.04971898,  0.00126183,
#           0.00191801,  0.02120853, -0.02249232, -0.0469758 ,
#          -0.03946502, -0.01758037],
#         [-0.03664522,  0.00044625, -0.00303239, -0.03876908,
#          -0.01665741, -0.01964722, -0.01451094, -0.00168437,
#           0.04596397,  0.04579471],
#         [ 0.00603824,  0.03994807, -0.03527318,  0.00937679,
#           0.02671001, -0.0464789 ,  0.02131745,  0.01405971,
#          -0.01715529,  0.02145449],
#         [ 0.00036553,  0.00285753, -0.03036636, -0.0220444 ,
#          -0.009691  ,  0.01123976,  0.0419068 , -0.01037778,
#          -0.03756368,  0.00809528]],
#
#        [[-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [ 0.02090422,  0.03870109, -0.04971898,  0.00126183,
#           0.00191801,  0.02120853, -0.02249232, -0.0469758 ,
#          -0.03946502, -0.01758037],
#         [-0.03664522,  0.00044625, -0.00303239, -0.03876908,
#          -0.01665741, -0.01964722, -0.01451094, -0.00168437,
#           0.04596397,  0.04579471],
#         [ 0.00603824,  0.03994807, -0.03527318,  0.00937679,
#           0.02671001, -0.0464789 ,  0.02131745,  0.01405971,
#          -0.01715529,  0.02145449],
#         [ 0.00130898,  0.0101833 , -0.04426525, -0.03110286,
#           0.01416656, -0.00320721,  0.02803968, -0.02020131,
#          -0.00260729,  0.01898732]],
#
#        [[-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [ 0.02090422,  0.03870109, -0.04971898,  0.00126183,
#           0.00191801,  0.02120853, -0.02249232, -0.0469758 ,
#          -0.03946502, -0.01758037],
#         [-0.00750633, -0.03167871,  0.0413583 , -0.03153193,
#          -0.00354992, -0.03396793,  0.01893942, -0.04319177,
#          -0.0076011 ,  0.04036594],
#         [ 0.00603824,  0.03994807, -0.03527318,  0.00937679,
#           0.02671001, -0.0464789 ,  0.02131745,  0.01405971,
#          -0.01715529,  0.02145449],
#         [ 0.04796772, -0.02092637,  0.02414897,  0.01039148,
#           0.03438381, -0.00800885, -0.03547094, -0.04853995,
#           0.00111722, -0.01769356]],
#
#        [[-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.03527876, -0.01521299,  0.02843842, -0.04039565,
#           0.03309162,  0.02288585, -0.04918298, -0.02699807,
#          -0.0015104 , -0.04314632],
#         [ 0.04611529, -0.00134225, -0.04995216, -0.0402777 ,
#          -0.03349356, -0.04507124, -0.04099949,  0.02105239,
#           0.03044107, -0.00752623],
#         [ 0.04993441, -0.01483225,  0.00761773,  0.01924895,
#           0.00571247,  0.02190861,  0.03540531, -0.02640724,
#          -0.03140705,  0.01864203],
#         [ 0.04211468, -0.02198451, -0.02323972, -0.03017941,
#          -0.02672733,  0.01435293,  0.00889647,  0.04164288,
#           0.04327205,  0.01754408],
#         [-0.00424374, -0.01089796,  0.04592865,  0.02544856,
#          -0.04871674, -0.00605744, -0.03606303,  0.02873809,
#           0.03233781, -0.02217418]],
#
#        [[-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.03527876, -0.01521299,  0.02843842, -0.04039565,
#           0.03309162,  0.02288585, -0.04918298, -0.02699807,
#          -0.0015104 , -0.04314632],
#         [ 0.04611529, -0.00134225, -0.04995216, -0.0402777 ,
#          -0.03349356, -0.04507124, -0.04099949,  0.02105239,
#           0.03044107, -0.00752623],
#         [ 0.04993441, -0.01483225,  0.00761773,  0.01924895,
#           0.00571247,  0.02190861,  0.03540531, -0.02640724,
#          -0.03140705,  0.01864203],
#         [ 0.04211468, -0.02198451, -0.02323972, -0.03017941,
#          -0.02672733,  0.01435293,  0.00889647,  0.04164288,
#           0.04327205,  0.01754408],
#         [ 0.00139393, -0.01910937,  0.00608609, -0.02262926,
#          -0.04049269,  0.00642458, -0.04451321, -0.01867294,
#           0.04917997,  0.01892335]],
#
#        [[-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [ 0.03211777,  0.02861602,  0.02785733,  0.01577182,
#           0.00557888, -0.00244602, -0.03282579,  0.03910348,
#          -0.02214168, -0.04802556],
#         [ 0.02090422,  0.03870109, -0.04971898,  0.00126183,
#           0.00191801,  0.02120853, -0.02249232, -0.0469758 ,
#          -0.03946502, -0.01758037],
#         [ 0.00594951,  0.01602862,  0.02834085,  0.00700493,
#          -0.0298833 ,  0.04791373, -0.01337749, -0.04661005,
#           0.01658924, -0.00983725],
#         [ 0.00603824,  0.03994807, -0.03527318,  0.00937679,
#           0.02671001, -0.0464789 ,  0.02131745,  0.01405971,
#          -0.01715529,  0.02145449],
#         [ 0.03345415, -0.03964038, -0.04962885,  0.03402233,
#          -0.0268646 ,  0.01540694,  0.03291652, -0.00021772,
#          -0.02766032, -0.00154578]],
#
#        [[-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.02091661, -0.02187305, -0.04524603, -0.01297382,
#           0.01357775, -0.03737284, -0.0329603 , -0.03424827,
#           0.02813703,  0.01939337],
#         [ 0.03942959,  0.00011636,  0.02907993,  0.02207595,
#           0.01136972,  0.02965999,  0.03075177,  0.03452117,
#           0.0052628 , -0.00754827],
#         [ 0.02645629, -0.01676846,  0.00207591,  0.01011126,
#          -0.01735272,  0.0255178 , -0.04588374,  0.01621553,
#           0.03951712, -0.0006382 ],
#         [ 0.04211468, -0.02198451, -0.02323972, -0.03017941,
#          -0.02672733,  0.01435293,  0.00889647,  0.04164288,
#           0.04327205,  0.01754408]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 7218, 2478, 3743, 2866], dtype=int32)

# %%
model.predict(embedded_docs[0].reshape(1, -1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# array([[[-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [-0.01511855, -0.02393634, -0.0422629 , -0.00485667,
#           0.00697824, -0.04767   ,  0.04787428, -0.03036904,
#           0.03097827, -0.02054119],
#         [ 0.02090422,  0.03870109, -0.04971898,  0.00126183,
#           0.00191801,  0.02120853, -0.02249232, -0.0469758 ,
#          -0.03946502, -0.01758037],
#         [-0.03664522,  0.00044625, -0.00303239, -0.03876908,
#          -0.01665741, -0.01964722, -0.01451094, -0.00168437,
#           0.04596397,  0.04579471],
#         [ 0.00603824,  0.03994807, -0.03527318,  0.00937679,
#           0.02671001, -0.0464789 ,  0.02131745,  0.01405971,
#          -0.01715529,  0.02145449],
#         [ 0.00036553,  0.00285753, -0.03036636, -0.0220444 ,
#          -0.009691  ,  0.01123976,  0.0419068 , -0.01037778,
#          -0.03756368,  0.00809528]]], dtype=float32)
